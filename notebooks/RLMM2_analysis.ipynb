# %% [markdown]
# # RL tabular MM analysis
# Set parameters, optionally run `config` with `--mm-type rl_tabular`, then plot PnL, rewards, actions, inventory, and spread.

# %%
import subprocess
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

pd.set_option('display.max_rows', 50)
pd.set_option('display.max_colwidth', None)

params = {
    # run controls
    'run_rl': True,
    'run_simple': True,

    # core config
    'config': 'config',
    'ticker': 'AAPL',
    'date': '20000101',
    'start': '00:00:01',
    'end': '01:00:00',
    'seed': 44524,

    # market makers
    'mm_type': 'RLMM2',
    'mm_type_simple': 'simple',
    'mm_wake': '3s',
    'mm_size': 10,
    'mm_inventory_limit': 100,

    # OU / fundamentals
    'fund_vol': 5e-9,           # sigma_s in oracle diffusion off below
    'ou_half_life': '30m',
    'value_r_bar': 100_000,     # cents ($1000)
    'value_sigma_n': None,
    'value_kappa': 3.85e-13,    # ln(2)/30m per ns
    'value_lambda_a': None,
    'sigma_s': 0,               # diffusion term off

    # megashock (oracle) settings
    'megashock_lambda_a': 2.7e-18,
    'megashock_mean': 1e3,
    'megashock_var': 5e4,

    # logging
    'log_name': 'RLMM2_seed_123456',
    'simple_log_name': 'simple_seed_123456',

    # noise traders
    'noise_count': 20,
    'noise_cash': 10_000_000,
    'noise_wake_freq': '10s',

    # value traders
    'value_count': 50,
    'value_cash': 10_000_000,

    # ZI traders
    'zi_count': 40,
    'zi_cash': 10_000_000,
    'zi_sigma_n': 10_000,
    'zi_sigma_s': None,
    'zi_kappa': None,
    'zi_r_bar': None,
    'zi_q_max': 10,
    'zi_sigma_pv': 5e4,
    'zi_R_min': 0,
    'zi_R_max': 100,
    'zi_eta': 1.0,
    'zi_lambda_a': 1e-12,

    # HBL / momentum
    'hbl_count': 0,
    'momentum_count': 0,
    'momentum_cash': 10_000_000,
    'momentum_min_size': 1,
    'momentum_max_size': 10,
    'momentum_wake': '20s',
}

repo_root = Path('..')
params['log_dir'] = repo_root / 'log' / params['log_name']
params['simple_log_dir'] = repo_root / 'log' / params['simple_log_name']

print('RL log dir:', params['log_dir'].resolve())
print('Simple log dir:', params['simple_log_dir'].resolve())
# Out:
# RL log dir: /Users/salim/Desktop/Columbia/Assignments_Columbia/S3/Reinforcement Learning/Project/ABIDES/abides/log/RLMM2_seed_123456
# Simple log dir: /Users/salim/Desktop/Columbia/Assignments_Columbia/S3/Reinforcement Learning/Project/ABIDES/abides/log/simple_seed_123456

# %% [markdown]
# ## Run simulation (optional)

# %%
def add_opt(cmd, flag, value):
    if value is not None:
        cmd.extend([flag, str(value)])

if params['run_rl']:
    cmd = [
        'python', 'main.py',
        '-c', params['config'],
        '-t', params['ticker'],
        '-d', params['date'],
        '--start-time', params['start'],
        '--end-time', params['end'],
        '--seed', str(params['seed']),
        '--log_dir', params['log_name'],
        '--mm-type', params['mm_type'],
        '--mm-wake-up-freq', params['mm_wake'],
        '--mm-size', str(params['mm_size']),
        '--mm-inventory-limit', str(params['mm_inventory_limit']),
        '--fund-vol', str(params['fund_vol']),
        '--noise-count', str(params['noise_count']),
        '--noise-cash', str(params['noise_cash']),
        '--value-count', str(params['value_count']),
        '--value-cash', str(params['value_cash']),
        '--zi-count', str(params['zi_count']),
        '--zi-cash', str(params['zi_cash']),
        '--zi-sigma-n', str(params['zi_sigma_n']),
        '--zi-q-max', str(params['zi_q_max']),
        '--zi-sigma-pv', str(params['zi_sigma_pv']),
        '--zi-R-min', str(params['zi_R_min']),
        '--zi-R-max', str(params['zi_R_max']),
        '--zi-eta', str(params['zi_eta']),
        '--zi-lambda-a', str(params['zi_lambda_a']),
        '--hbl-count', str(params['hbl_count']),
        '--momentum-count', str(params['momentum_count']),
        '--momentum-cash', str(params['momentum_cash']),
        '--momentum-min-size', str(params['momentum_min_size']),
        '--momentum-max-size', str(params['momentum_max_size']),
        '--momentum-wake', params['momentum_wake'],
    ]
    add_opt(cmd, '--value-sigma-n', params['value_sigma_n'])
    add_opt(cmd, '--value-r-bar', params['value_r_bar'])
    add_opt(cmd, '--value-kappa', params['value_kappa'])
    add_opt(cmd, '--value-lambda-a', params['value_lambda_a'])
    add_opt(cmd, '--zi-sigma-s', params['zi_sigma_s'])
    add_opt(cmd, '--zi-kappa', params['zi_kappa'])
    add_opt(cmd, '--zi-r-bar', params['zi_r_bar'])
    print('Running RL:', ' '.join(cmd))
    result = subprocess.run(cmd, cwd=repo_root)
    print('RL return code:', result.returncode)
else:
    print('Skipping RL run; set params["run_rl"] = True to execute.')

if params['run_simple']:
    cmd_simple = [
        'python', 'main.py',
        '-c', params['config'],
        '-t', params['ticker'],
        '-d', params['date'],
        '--start-time', params['start'],
        '--end-time', params['end'],
        '--seed', str(params['seed']),
        '--log_dir', params['simple_log_name'],
        '--mm-type', params['mm_type_simple'],
        '--mm-wake-up-freq', params['mm_wake'],
        '--mm-size', str(params['mm_size']),
        '--mm-inventory-limit', str(params['mm_inventory_limit']),
        '--fund-vol', str(params['fund_vol']),
        '--noise-count', str(params['noise_count']),
        '--noise-cash', str(params['noise_cash']),
        '--value-count', str(params['value_count']),
        '--value-cash', str(params['value_cash']),
        '--zi-count', str(params['zi_count']),
        '--zi-cash', str(params['zi_cash']),
        '--zi-sigma-n', str(params['zi_sigma_n']),
        '--zi-q-max', str(params['zi_q_max']),
        '--zi-sigma-pv', str(params['zi_sigma_pv']),
        '--zi-R-min', str(params['zi_R_min']),
        '--zi-R-max', str(params['zi_R_max']),
        '--zi-eta', str(params['zi_eta']),
        '--zi-lambda-a', str(params['zi_lambda_a']),
        '--hbl-count', str(params['hbl_count']),
        '--momentum-count', str(params['momentum_count']),
        '--momentum-cash', str(params['momentum_cash']),
        '--momentum-min-size', str(params['momentum_min_size']),
        '--momentum-max-size', str(params['momentum_max_size']),
        '--momentum-wake', params['momentum_wake'],
    ]
    add_opt(cmd_simple, '--value-sigma-n', params['value_sigma_n'])
    add_opt(cmd_simple, '--value-r-bar', params['value_r_bar'])
    add_opt(cmd_simple, '--value-kappa', params['value_kappa'])
    add_opt(cmd_simple, '--value-lambda-a', params['value_lambda_a'])
    add_opt(cmd_simple, '--zi-sigma-s', params['zi_sigma_s'])
    add_opt(cmd_simple, '--zi-kappa', params['zi_kappa'])
    add_opt(cmd_simple, '--zi-r-bar', params['zi_r_bar'])
    print('Running simple MM:', ' '.join(cmd_simple))
    result_simple = subprocess.run(cmd_simple, cwd=repo_root)
    print('Simple return code:', result_simple.returncode)
else:
    print('Skipping simple MM run; set params["run_simple"] = True to execute.')
# Out:
# Running RL: python main.py -c config -t AAPL -d 20000101 --start-time 00:00:01 --end-time 01:00:00 --seed 44524 --log_dir RLMM2_seed_123456 --mm-type RLMM2 --mm-wake-up-freq 3s --mm-size 10 --mm-inventory-limit 100 --fund-vol 5e-09 --noise-count 20 --noise-cash 10000000 --value-count 50 --value-cash 10000000 --zi-count 40 --zi-cash 10000000 --zi-sigma-n 10000 --zi-q-max 10 --zi-sigma-pv 50000.0 --zi-R-min 0 --zi-R-max 100 --zi-eta 1.0 --zi-lambda-a 1e-12 --hbl-count 0 --momentum-count 0 --momentum-cash 10000000 --momentum-min-size 1 --momentum-max-size 10 --momentum-wake 20s --value-r-bar 100000 --value-kappa 3.85e-13
# ===========================
# Beginning of the simulation
# ===========================
#
# [config] start_wall=2025-12-05 17:28:18.802405
# [config] seed=44524
#
# [kernel] t=2001-01-01 00:00:00 processed=0
# [kernel] t=2001-01-01 00:39:51.411362198 processed=100000
# Final holdings for NoiseTrader 1: { AAPL: -344, CASH: 44374640 }.  Marked to market: 9975328
# Final holdings for NoiseTrader 2: { AAPL: -266, CASH: 36596173 }.  Marked to market: 9996705
# Final holdings for NoiseTrader 3: { AAPL: 1315, CASH: -121487914 }.  Marked to market: 10009456
# Final holdings for NoiseTrader 4: { AAPL: 221, CASH: -12117936 }.  Marked to market: 9981622
# Final holdings for NoiseTrader 5: { AAPL: -1248, CASH: 134774402 }.  Marked to market: 9976898
# Final holdings for NoiseTrader 6: { AAPL: 1873, CASH: -177235022 }.  Marked to market: 10061232
# Final holdings for NoiseTrader 7: { AAPL: -375, CASH: 47474750 }.  Marked to market: 9975500
# Final holdings for NoiseTrader 8: { AAPL: 1551, CASH: -145056213 }.  Marked to market: 10040685
# Final holdings for NoiseTrader 9: { AAPL: 328, CASH: -22807476 }.  Marked to market: 9991868
# Final holdings for NoiseTrader 10: { AAPL: -412, CASH: 51165487 }.  Marked to market: 9966311
# Final holdings for NoiseTrader 11: { AAPL: 883, CASH: -78269401 }.  Marked to market: 10028833
# Final holdings for NoiseTrader 12: { AAPL: -311, CASH: 40996328 }.  Marked to market: 9896950
# Final holdings for NoiseTrader 13: { AAPL: -260, CASH: 35954291 }.  Marked to market: 9954811
# Final holdings for NoiseTrader 14: { AAPL: -229, CASH: 32862885 }.  Marked to market: 9963343
# Final holdings for NoiseTrader 15: { AAPL: 140, CASH: -4019022 }.  Marked to market: 9980698
# Final holdings for NoiseTrader 16: { AAPL: -326, CASH: 42563876 }.  Marked to market: 9964528
# Final holdings for NoiseTrader 17: { AAPL: -1127, CASH: 122661099 }.  Marked to market: 9963353
# Final holdings for NoiseTrader 18: { AAPL: -363, CASH: 46272608 }.  Marked to market: 9973334
# Final holdings for NoiseTrader 19: { AAPL: 63, CASH: 3675609 }.  Marked to market: 9975483
# Final holdings for NoiseTrader 20: { AAPL: -277, CASH: 37660079 }.  Marked to market: 9960633
# Final holdings for ValueTrader 21: { AAPL: -41, CASH: 14100870 }.  Marked to market: 10000952
# Final holdings for ValueTrader 22: { AAPL: -46, CASH: 14602611 }.  Marked to market: 10002703
# Final holdings for ValueTrader 23: { AAPL: -139, CASH: 23901826 }.  Marked to market: 10002104
# Final holdings for ValueTrader 24: { AAPL: -61, CASH: 16101783 }.  Marked to market: 10001905
# Final holdings for ValueTrader 25: { AAPL: -206, CASH: 30603003 }.  Marked to market: 10003415
# Final holdings for ValueTrader 26: { AAPL: -78, CASH: 17804323 }.  Marked to market: 10004479
# Final holdings for ValueTrader 27: { AAPL: -46, CASH: 14601678 }.  Marked to market: 10001770
# Final holdings for ValueTrader 28: { AAPL: -63, CASH: 16302638 }.  Marked to market: 10002764
# Final holdings for ValueTrader 29: { AAPL: -120, CASH: 22003058 }.  Marked to market: 10003298
# Final holdings for ValueTrader 30: { AAPL: -15, CASH: 11500497 }.  Marked to market: 10000527
# Final holdings for ValueTrader 31: { AAPL: -13, CASH: 11304154 }.  Marked to market: 10004180
# Final holdings for ValueTrader 32: { AAPL: -23, CASH: 12303638 }.  Marked to market: 10003684
# Final holdings for ValueTrader 33: { AAPL: -44, CASH: 14407815 }.  Marked to market: 10007903
# Final holdings for ValueTrader 34: { AAPL: -87, CASH: 18703547 }.  Marked to market: 10003721
# Final holdings for ValueTrader 35: { AAPL: -25, CASH: 12505335 }.  Marked to market: 10005385
# Final holdings for ValueTrader 36: { AAPL: -69, CASH: 16903031 }.  Marked to market: 10003169
# Final holdings for ValueTrader 37: { AAPL: -50, CASH: 15009185 }.  Marked to market: 10009285
# Final holdings for ValueTrader 38: { AAPL: -41, CASH: 14104579 }.  Marked to market: 10004661
# Final holdings for ValueTrader 39: { AAPL: -22, CASH: 12201061 }.  Marked to market: 10001105
# Final holdings for ValueTrader 40: { AAPL: -20, CASH: 12002922 }.  Marked to market: 10002962
# Final holdings for ValueTrader 41: { AAPL: -53, CASH: 15300225 }.  Marked to market: 10000331
# Final holdings for ValueTrader 42: { AAPL: -26, CASH: 12601099 }.  Marked to market: 10001151
# Final holdings for ValueTrader 43: { AAPL: -47, CASH: 14702308 }.  Marked to market: 10002402
# Final holdings for ValueTrader 44: { AAPL: -17, CASH: 11705560 }.  Marked to market: 10005594
# Final holdings for ValueTrader 45: { AAPL: -45, CASH: 14504600 }.  Marked to market: 10004690
# Final holdings for ValueTrader 46: { AAPL: -3, CASH: 10300947 }.  Marked to market: 10000953
# Final holdings for ValueTrader 47: { AAPL: -75, CASH: 17504361 }.  Marked to market: 10004511
# Final holdings for ValueTrader 48: { AAPL: -145, CASH: 24505325 }.  Marked to market: 10005615
# Final holdings for ValueTrader 49: { AAPL: -57, CASH: 15702017 }.  Marked to market: 10002131
# Final holdings for ValueTrader 50: { AAPL: -177, CASH: 27704471 }.  Marked to market: 10004825
# Final holdings for ValueTrader 51: { AAPL: -10, CASH: 11003387 }.  Marked to market: 10003407
# Final holdings for ValueTrader 52: { AAPL: -12, CASH: 11203710 }.  Marked to market: 10003734
# Final holdings for ValueTrader 53: { AAPL: -21, CASH: 12105950 }.  Marked to market: 10005992
# Final holdings for ValueTrader 54: { AAPL: -47, CASH: 14702858 }.  Marked to market: 10002952
# Final holdings for ValueTrader 55: { AAPL: -72, CASH: 17203450 }.  Marked to market: 10003594
# Final holdings for ValueTrader 56: { AAPL: -102, CASH: 20204758 }.  Marked to market: 10004962
# Final holdings for ValueTrader 57: { AAPL: -118, CASH: 21802091 }.  Marked to market: 10002327
# Final holdings for ValueTrader 58: { AAPL: -35, CASH: 13501220 }.  Marked to market: 10001290
# Final holdings for ValueTrader 59: { AAPL: -30, CASH: 13005567 }.  Marked to market: 10005627
# Final holdings for ValueTrader 60: { AAPL: -61, CASH: 16105800 }.  Marked to market: 10005922
# Final holdings for ValueTrader 61: { AAPL: -86, CASH: 18601446 }.  Marked to market: 10001618
# Final holdings for ValueTrader 62: { AAPL: -87, CASH: 18703430 }.  Marked to market: 10003604
# Final holdings for ValueTrader 63: { AAPL: -76, CASH: 17604147 }.  Marked to market: 10004299
# Final holdings for ValueTrader 64: { AAPL: -32, CASH: 13200365 }.  Marked to market: 10000429
# Final holdings for ValueTrader 65: { AAPL: -12, CASH: 11202183 }.  Marked to market: 10002207
# Final holdings for ValueTrader 66: { AAPL: -240, CASH: 34004819 }.  Marked to market: 10005299
# Final holdings for ValueTrader 67: { AAPL: -58, CASH: 15802935 }.  Marked to market: 10003051
# Final holdings for ValueTrader 68: { AAPL: -32, CASH: 13200899 }.  Marked to market: 10000963
# Final holdings for ValueTrader 69: { AAPL: -34, CASH: 13400949 }.  Marked to market: 10001017
# Final holdings for ValueTrader 70: { AAPL: -109, CASH: 20906001 }.  Marked to market: 10006219
# Final holdings for RL_MM2_0: { AAPL: -93, CASH: 19286407 }.  Marked to market: 9986593
# Final holdings for ZI_TRADER_72: { AAPL: -100, CASH: 19993700 }.  Marked to market: 10003600
# Final holdings for ZI_TRADER_73: { AAPL: 100, CASH: 5400 }.  Marked to market: 10000000
# Final holdings for ZI_TRADER_74: { AAPL: 200, CASH: -9996000 }.  Marked to market: 10000600
# Final holdings for ZI_TRADER_75: { AAPL: 100, CASH: 6300 }.  Marked to market: 10004500
# Final holdings for ZI_TRADER_76: { AAPL: 100, CASH: 2800 }.  Marked to market: 9997700
# Final holdings for ZI_TRADER_77: { AAPL: 100, CASH: 500 }.  Marked to market: 10000800
# Final holdings for ZI_TRADER_78: { AAPL: 100, CASH: 4800 }.  Marked to market: 10000000
# Final holdings for ZI_TRADER_79: { AAPL: -200, CASH: 30010200 }.  Marked to market: 10024400
# Final holdings for ZI_TRADER_80: { AAPL: 200, CASH: -9995100 }.  Marked to market: 9995300
# Final holdings for ZI_TRADER_81: { AAPL: -100, CASH: 20002800 }.  Marked to market: 10001400
# Final holdings for ZI_TRADER_82: { AAPL: 200, CASH: -10001800 }.  Marked to market: 9987800
# Final holdings for ZI_TRADER_83: { AAPL: 200, CASH: -9983297 }.  Marked to market: 10007703
# Final holdings for ZI_TRADER_84: { AAPL: 100, CASH: 8700 }.  Marked to market: 10004500
# Final holdings for ZI_TRADER_85: { AAPL: -100, CASH: 20012200 }.  Marked to market: 10014900
# Final holdings for ZI_TRADER_86: { AAPL: 100, CASH: 6900 }.  Marked to market: 10000800
# Final holdings for ZI_TRADER_87: { AAPL: 400, CASH: -29987200 }.  Marked to market: 9996400
# Final holdings for ZI_TRADER_88: { AAPL: 286, CASH: -18582610 }.  Marked to market: 10016818
# Final holdings for ZI_TRADER_89: { AAPL: -300, CASH: 39994700 }.  Marked to market: 9995300
# Final holdings for ZI_TRADER_90: { AAPL: 300, CASH: -19986900 }.  Marked to market: 9987900
# Final holdings for ZI_TRADER_91: { AAPL: 200, CASH: -9998700 }.  Marked to market: 9999100
# Final holdings for ZI_TRADER_92: { AAPL: -100, CASH: 20001800 }.  Marked to market: 10010700
# Final holdings for ZI_TRADER_93: { AAPL: -100, CASH: 20000600 }.  Marked to market: 10009000
# Final holdings for ZI_TRADER_94: { AAPL: 200, CASH: -9989900 }.  Marked to market: 10006700
# Final holdings for ZI_TRADER_95: { AAPL: 100, CASH: 0 }.  Marked to market: 10000000
# Final holdings for ZI_TRADER_96: { AAPL: 166, CASH: -6596844 }.  Marked to market: 9992200
# Final holdings for ZI_TRADER_97: { AAPL: -203, CASH: 30307085 }.  Marked to market: 10010130
# Final holdings for ZI_TRADER_98: { CASH: 10010900 }.  Marked to market: 10010900
# Final holdings for ZI_TRADER_99: { AAPL: -300, CASH: 39995800 }.  Marked to market: 9996400
# Final holdings for ZI_TRADER_100: { CASH: 10000000 }.  Marked to market: 10000000
# Final holdings for ZI_TRADER_101: { AAPL: 200, CASH: -9997700 }.  Marked to market: 9992300
# Final holdings for ZI_TRADER_102: { CASH: 10010500 }.  Marked to market: 10010500
# Final holdings for ZI_TRADER_103: { CASH: 10000000 }.  Marked to market: 10000000
# Final holdings for ZI_TRADER_104: { CASH: 10010300 }.  Marked to market: 10010300
# Final holdings for ZI_TRADER_105: { AAPL: 300, CASH: -19996400 }.  Marked to market: 10001800
# Final holdings for ZI_TRADER_106: { AAPL: 141, CASH: -4088496 }.  Marked to market: 10007838
# Final holdings for ZI_TRADER_107: { AAPL: -105, CASH: 20500580 }.  Marked to market: 10008770
# Final holdings for ZI_TRADER_108: { AAPL: -200, CASH: 29992000 }.  Marked to market: 9998800
# Final holdings for ZI_TRADER_109: { AAPL: 200, CASH: -10002600 }.  Marked to market: 9987200
# Final holdings for ZI_TRADER_110: { AAPL: 100, CASH: 19600 }.  Marked to market: 10011400
# Final holdings for ZI_TRADER_111: { AAPL: 100, CASH: 15300 }.  Marked to market: 10013800
# [exchange] archiving order book for AAPL ...
# Processing orderbook log: 100%|██████████| 23158/23158 [00:19<00:00, 1163.28it/s]
# [exchange] order book logging duration: 0:00:27.406992
# [exchange] order book archival complete
# [kernel] queue_elapsed=0 days 00:00:19.620411 messages=151089 rate=7700.6/s
# [kernel] simulation ending
# [config] end_wall=2025-12-05 17:29:09.208487
# [config] duration=0:00:50.406082
# RL return code: 0
# Running simple MM: python main.py -c config -t AAPL -d 20000101 --start-time 00:00:01 --end-time 01:00:00 --seed 44524 --log_dir simple_seed_123456 --mm-type simple --mm-wake-up-freq 3s --mm-size 10 --mm-inventory-limit 100 --fund-vol 5e-09 --noise-count 20 --noise-cash 10000000 --value-count 50 --value-cash 10000000 --zi-count 40 --zi-cash 10000000 --zi-sigma-n 10000 --zi-q-max 10 --zi-sigma-pv 50000.0 --zi-R-min 0 --zi-R-max 100 --zi-eta 1.0 --zi-lambda-a 1e-12 --hbl-count 0 --momentum-count 0 --momentum-cash 10000000 --momentum-min-size 1 --momentum-max-size 10 --momentum-wake 20s --value-r-bar 100000 --value-kappa 3.85e-13
# ===========================
# Beginning of the simulation
# ===========================
#
# [config] start_wall=2025-12-05 17:29:10.787425
# [config] seed=44524
#
# [kernel] t=2001-01-01 00:00:00 processed=0
# [kernel] t=2001-01-01 00:40:02.536243123 processed=100000
# Final holdings for NoiseTrader 1: { AAPL: -350, CASH: 44966298 }.  Marked to market: 9980298
# Final holdings for NoiseTrader 2: { AAPL: -178, CASH: 27809625 }.  Marked to market: 10016745
# Final holdings for NoiseTrader 3: { AAPL: 1295, CASH: -119572281 }.  Marked to market: 9875919
# Final holdings for NoiseTrader 4: { AAPL: 211, CASH: -11108974 }.  Marked to market: 9982586
# Final holdings for NoiseTrader 5: { AAPL: -1189, CASH: 128868595 }.  Marked to market: 10016155
# Final holdings for NoiseTrader 6: { AAPL: 1933, CASH: -183276940 }.  Marked to market: 9945740
# Final holdings for NoiseTrader 7: { AAPL: -332, CASH: 43176446 }.  Marked to market: 9989726
# Final holdings for NoiseTrader 8: { AAPL: 1490, CASH: -138993694 }.  Marked to market: 9946706
# Final holdings for NoiseTrader 9: { AAPL: 317, CASH: -21714202 }.  Marked to market: 9973118
# Final holdings for NoiseTrader 10: { AAPL: -390, CASH: 48965200 }.  Marked to market: 9980800
# Final holdings for NoiseTrader 11: { AAPL: 844, CASH: -74429332 }.  Marked to market: 9936908
# Final holdings for NoiseTrader 12: { AAPL: -297, CASH: 39546106 }.  Marked to market: 9857986
# Final holdings for NoiseTrader 13: { AAPL: -257, CASH: 35654186 }.  Marked to market: 9964466
# Final holdings for NoiseTrader 14: { AAPL: -123, CASH: 22280591 }.  Marked to market: 9985511
# Final holdings for NoiseTrader 15: { AAPL: 191, CASH: -9148897 }.  Marked to market: 9943463
# Final holdings for NoiseTrader 16: { AAPL: -297, CASH: 39680869 }.  Marked to market: 9992749
# Final holdings for NoiseTrader 17: { AAPL: -1171, CASH: 127084352 }.  Marked to market: 10031192
# Final holdings for NoiseTrader 18: { AAPL: -381, CASH: 48098672 }.  Marked to market: 10013912
# Final holdings for NoiseTrader 19: { AAPL: 139, CASH: -3943100 }.  Marked to market: 9951340
# Final holdings for NoiseTrader 20: { AAPL: -206, CASH: 30579757 }.  Marked to market: 9987997
# Final holdings for ValueTrader 21: { AAPL: -31, CASH: 13102106 }.  Marked to market: 10003346
# Final holdings for ValueTrader 22: { AAPL: -59, CASH: 15904473 }.  Marked to market: 10006833
# Final holdings for ValueTrader 23: { AAPL: -127, CASH: 22705313 }.  Marked to market: 10010393
# Final holdings for ValueTrader 24: { AAPL: -24, CASH: 12402615 }.  Marked to market: 10003575
# Final holdings for ValueTrader 25: { AAPL: -106, CASH: 20612605 }.  Marked to market: 10016845
# Final holdings for ValueTrader 26: { AAPL: -102, CASH: 20206937 }.  Marked to market: 10011017
# Final holdings for ValueTrader 27: { AAPL: -48, CASH: 14802071 }.  Marked to market: 10003991
# Final holdings for ValueTrader 28: { AAPL: -56, CASH: 15602495 }.  Marked to market: 10004735
# Final holdings for ValueTrader 29: { AAPL: -91, CASH: 19108983 }.  Marked to market: 10012623
# Final holdings for ValueTrader 30: { AAPL: -4, CASH: 10401505 }.  Marked to market: 10001665
# Final holdings for ValueTrader 31: { AAPL: 27, CASH: 7306041 }.  Marked to market: 10004961
# Final holdings for ValueTrader 32: { AAPL: -18, CASH: 11802100 }.  Marked to market: 10002820
# Final holdings for ValueTrader 33: { AAPL: -141, CASH: 24108106 }.  Marked to market: 10013746
# Final holdings for ValueTrader 34: { AAPL: -31, CASH: 13111551 }.  Marked to market: 10012791
# Final holdings for ValueTrader 35: { AAPL: -129, CASH: 22908510 }.  Marked to market: 10013670
# Final holdings for ValueTrader 36: { AAPL: -76, CASH: 17604656 }.  Marked to market: 10007696
# Final holdings for ValueTrader 37: { AAPL: -98, CASH: 19810346 }.  Marked to market: 10014266
# Final holdings for ValueTrader 38: { AAPL: -80, CASH: 18008869 }.  Marked to market: 10012069
# Final holdings for ValueTrader 39: { AAPL: -29, CASH: 12902064 }.  Marked to market: 10003224
# Final holdings for ValueTrader 40: { AAPL: -9, CASH: 10901988 }.  Marked to market: 10002348
# Final holdings for ValueTrader 41: { AAPL: -23, CASH: 12304897 }.  Marked to market: 10005817
# Final holdings for ValueTrader 42: { AAPL: -50, CASH: 15002228 }.  Marked to market: 10004228
# Final holdings for ValueTrader 43: { AAPL: -61, CASH: 16106441 }.  Marked to market: 10008881
# Final holdings for ValueTrader 44: { AAPL: -48, CASH: 14802650 }.  Marked to market: 10004570
# Final holdings for ValueTrader 45: { AAPL: -94, CASH: 19404313 }.  Marked to market: 10008073
# Final holdings for ValueTrader 46: { AAPL: -18, CASH: 11801860 }.  Marked to market: 10002580
# Final holdings for ValueTrader 47: { AAPL: -107, CASH: 20705218 }.  Marked to market: 10009498
# Final holdings for ValueTrader 48: { AAPL: -125, CASH: 22511544 }.  Marked to market: 10016544
# Final holdings for ValueTrader 49: { AAPL: -54, CASH: 15404128 }.  Marked to market: 10006288
# Final holdings for ValueTrader 50: { AAPL: -9, CASH: 10912046 }.  Marked to market: 10012406
# Final holdings for ValueTrader 51: { AAPL: -11, CASH: 11106946 }.  Marked to market: 10007386
# Final holdings for ValueTrader 52: { AAPL: -8, CASH: 10803484 }.  Marked to market: 10003804
# Final holdings for ValueTrader 53: { AAPL: -105, CASH: 20506018 }.  Marked to market: 10010218
# Final holdings for ValueTrader 54: { AAPL: -28, CASH: 12802139 }.  Marked to market: 10003259
# Final holdings for ValueTrader 55: { AAPL: -66, CASH: 16602670 }.  Marked to market: 10005310
# Final holdings for ValueTrader 56: { AAPL: -55, CASH: 15508098 }.  Marked to market: 10010298
# Final holdings for ValueTrader 57: { AAPL: -101, CASH: 20105749 }.  Marked to market: 10009789
# Final holdings for ValueTrader 58: { AAPL: -32, CASH: 13202197 }.  Marked to market: 10003477
# Final holdings for ValueTrader 59: { AAPL: -40, CASH: 14007467 }.  Marked to market: 10009067
# Final holdings for ValueTrader 60: { AAPL: -50, CASH: 15008050 }.  Marked to market: 10010050
# Final holdings for ValueTrader 61: { AAPL: -44, CASH: 14407480 }.  Marked to market: 10009240
# Final holdings for ValueTrader 62: { AAPL: -148, CASH: 24808608 }.  Marked to market: 10014528
# Final holdings for ValueTrader 63: { AAPL: -119, CASH: 21905308 }.  Marked to market: 10010068
# Final holdings for ValueTrader 64: { AAPL: -24, CASH: 12403378 }.  Marked to market: 10004338
# Final holdings for ValueTrader 65: { AAPL: -57, CASH: 15700563 }.  Marked to market: 10002843
# Final holdings for ValueTrader 66: { AAPL: -122, CASH: 22212986 }.  Marked to market: 10017866
# Final holdings for ValueTrader 67: { AAPL: -3, CASH: 10308182 }.  Marked to market: 10008302
# Final holdings for ValueTrader 68: { AAPL: -12, CASH: 11202384 }.  Marked to market: 10002864
# Final holdings for ValueTrader 69: { AAPL: -44, CASH: 14402335 }.  Marked to market: 10004095
# Final holdings for ValueTrader 70: { AAPL: -136, CASH: 23610952 }.  Marked to market: 10016392
# Final holdings for SIMPLE_MM_0: { AAPL: -82, CASH: 18187742 }.  Marked to market: 9991022
# Final holdings for ZI_TRADER_72: { CASH: 10005000 }.  Marked to market: 10005000
# Final holdings for ZI_TRADER_73: { AAPL: 100, CASH: 6900 }.  Marked to market: 10000000
# Final holdings for ZI_TRADER_74: { AAPL: 200, CASH: -9998500 }.  Marked to market: 9992900
# Final holdings for ZI_TRADER_75: { AAPL: -47, CASH: 14712413 }.  Marked to market: 10011097
# Final holdings for ZI_TRADER_76: { AAPL: 200, CASH: -9983700 }.  Marked to market: 10013900
# Final holdings for ZI_TRADER_77: { CASH: 10009100 }.  Marked to market: 10009100
# Final holdings for ZI_TRADER_78: { AAPL: 100, CASH: 3900 }.  Marked to market: 9998100
# Final holdings for ZI_TRADER_79: { AAPL: -300, CASH: 40020800 }.  Marked to market: 10045100
# Final holdings for ZI_TRADER_80: { AAPL: 200, CASH: -9995300 }.  Marked to market: 9996700
# Final holdings for ZI_TRADER_81: { AAPL: -200, CASH: 30012000 }.  Marked to market: 10004600
# Final holdings for ZI_TRADER_82: { AAPL: 200, CASH: -10001800 }.  Marked to market: 9997200
# Final holdings for ZI_TRADER_83: { AAPL: 89, CASH: 1105482 }.  Marked to market: 10007974
# Final holdings for ZI_TRADER_84: { AAPL: 100, CASH: 6700 }.  Marked to market: 10008600
# Final holdings for ZI_TRADER_85: { AAPL: -100, CASH: 20015100 }.  Marked to market: 10010400
# Final holdings for ZI_TRADER_86: { CASH: 10000000 }.  Marked to market: 10000000
# Final holdings for ZI_TRADER_87: { AAPL: 475, CASH: -37493650 }.  Marked to market: 10015375
# Final holdings for ZI_TRADER_88: { AAPL: 194, CASH: -9375724 }.  Marked to market: 10016516
# Final holdings for ZI_TRADER_89: { AAPL: -200, CASH: 30012300 }.  Marked to market: 10020300
# Final holdings for ZI_TRADER_90: { AAPL: 300, CASH: -19990100 }.  Marked to market: 9987100
# Final holdings for ZI_TRADER_91: { AAPL: 200, CASH: -10002400 }.  Marked to market: 10002800
# Final holdings for ZI_TRADER_92: { AAPL: -100, CASH: 20001800 }.  Marked to market: 10009100
# Final holdings for ZI_TRADER_93: { AAPL: -100, CASH: 20000600 }.  Marked to market: 10007400
# Final holdings for ZI_TRADER_94: { AAPL: 100, CASH: 0 }.  Marked to market: 10002800
# Final holdings for ZI_TRADER_95: { AAPL: 100, CASH: 0 }.  Marked to market: 10000000
# Final holdings for ZI_TRADER_96: { AAPL: 138, CASH: -3798730 }.  Marked to market: 9992024
# Final holdings for ZI_TRADER_97: { AAPL: -150, CASH: 25000700 }.  Marked to market: 10007150
# Final holdings for ZI_TRADER_98: { CASH: 10009000 }.  Marked to market: 10009000
# Final holdings for ZI_TRADER_99: { AAPL: -300, CASH: 40004800 }.  Marked to market: 10016800
# Final holdings for ZI_TRADER_100: { AAPL: -100, CASH: 20004800 }.  Marked to market: 10012500
# Final holdings for ZI_TRADER_101: { AAPL: 200, CASH: -9995900 }.  Marked to market: 9994500
# Final holdings for ZI_TRADER_102: { CASH: 10009200 }.  Marked to market: 10009200
# Final holdings for ZI_TRADER_103: { AAPL: -100, CASH: 20004100 }.  Marked to market: 10004900
# Final holdings for ZI_TRADER_104: { CASH: 10025300 }.  Marked to market: 10025300
# Final holdings for ZI_TRADER_105: { AAPL: 300, CASH: -19999400 }.  Marked to market: 10011400
# Final holdings for ZI_TRADER_106: { AAPL: 100, CASH: 7500 }.  Marked to market: 10011300
# Final holdings for ZI_TRADER_107: { AAPL: -100, CASH: 20014500 }.  Marked to market: 10022700
# Final holdings for ZI_TRADER_108: { AAPL: -200, CASH: 30004300 }.  Marked to market: 10011700
# Final holdings for ZI_TRADER_109: { AAPL: 200, CASH: -10003500 }.  Marked to market: 9987100
# Final holdings for ZI_TRADER_110: { AAPL: 222, CASH: -12171875 }.  Marked to market: 10009033
# Final holdings for ZI_TRADER_111: { AAPL: 138, CASH: -3780388 }.  Marked to market: 10013678
# [exchange] archiving order book for AAPL ...
# Processing orderbook log: 100%|██████████| 22977/22977 [00:12<00:00, 1878.22it/s]
# [exchange] order book logging duration: 0:00:16.499947
# [exchange] order book archival complete
# [kernel] queue_elapsed=0 days 00:00:15.700341 messages=149991 rate=9553.4/s
# [kernel] simulation ending
# [config] end_wall=2025-12-05 17:29:44.652348
# [config] duration=0:00:33.864923
# Simple return code: 0

# %% [markdown]
# ### MTM comparison (RL vs simple)

# %%
# MTM comparison (aligned on time index)
log_dir = params['log_dir']
simple_log_dir = params['simple_log_dir']

rl_files = sorted(log_dir.glob('RL_MM2_*.bz2'))
rl_log = pd.read_pickle(rl_files[0]) if rl_files else pd.DataFrame()
state_rows = rl_log[rl_log['EventType'] == 'STATE'] if not rl_log.empty else pd.DataFrame()

simple_files = sorted(simple_log_dir.glob('SIMPLE_MM_*.bz2'))
simple_log = pd.read_pickle(simple_files[0]) if simple_files else pd.DataFrame()
simple_state_rows = simple_log[simple_log['EventType'] == 'STATE'] if not simple_log.empty else pd.DataFrame()

rl_state = None
simple_state = None
if not state_rows.empty:
    rl_state = pd.DataFrame(list(state_rows['Event'])).set_index('time')
    rl_state.index = pd.to_datetime(rl_state.index)
if not simple_state_rows.empty:
    simple_state = pd.DataFrame(list(simple_state_rows['Event'])).set_index('time')
    simple_state.index = pd.to_datetime(simple_state.index)

series = []
if rl_state is not None:
    series.append(rl_state['mtm'].rename('RLMM2'))
if simple_state is not None:
    series.append(simple_state['mtm'].rename('simpleMM'))

if series:
    df = pd.concat(series, axis=1).sort_index()
    df_resampled = df.resample('1min').last()
    title = 'MTM PnL comparison' if len(series) > 1 else 'MTM PnL (RL only)'
    ax = df_resampled.plot(figsize=(10,3), title=title)
    plt.legend()
    plt.tight_layout()
else:
    print('No STATE events found; nothing to plot')

# %% [markdown]
# ### Inventory comparison (RL vs simple)

# %%
# Plot inventories on common time grid
log_dir = params['log_dir']
simple_log_dir = params['simple_log_dir']

rl_files = list(log_dir.glob('RL_MM2_*.bz2'))
rl_log = pd.read_pickle(rl_files[0]) if rl_files else pd.DataFrame()
state_rows_rl = rl_log[rl_log['EventType'] == 'STATE'] if not rl_log.empty else pd.DataFrame()

simple_state_rows = None
if simple_log_dir:
    simple_files = list(simple_log_dir.glob('SIMPLE_MM_*.bz2'))
    simple_log = pd.read_pickle(simple_files[0]) if simple_files else pd.DataFrame()
    simple_state_rows = simple_log[simple_log['EventType'] == 'STATE'] if not simple_log.empty else pd.DataFrame()

rl_state = None
simple_state = None
if not state_rows_rl.empty:
    rl_state = pd.DataFrame(list(state_rows_rl['Event'])).set_index('time')
    rl_state.index = pd.to_datetime(rl_state.index)
if simple_state_rows is not None and not simple_state_rows.empty:
    simple_state = pd.DataFrame(list(simple_state_rows['Event'])).set_index('time')
    simple_state.index = pd.to_datetime(simple_state.index)

# Plot raw inventories
if rl_state is not None:
    ax = rl_state[['inventory']].plot(figsize=(10,3), title='Inventory (raw)', label='RLMM2')
    if simple_state is not None:
        simple_state[['inventory']].plot(ax=ax, label='simpleMM')
    plt.legend()
    plt.tight_layout()
else:
    print('No RL STATE events found; nothing to plot')

# Aligned on 1-minute grid
series = []
if rl_state is not None:
    series.append(rl_state['inventory'].rename('RLMM2'))
if simple_state is not None:
    series.append(simple_state['inventory'].rename('simpleMM'))

if series:
    df = pd.concat(series, axis=1).sort_index()
    df_resampled = df.resample('1min').last()
    title = 'Inventory comparison (1-minute resampled)' if len(series) > 1 else 'Inventory (1-minute resampled, RL only)'
    df_resampled.plot(figsize=(10,3), title=title)
    plt.legend()
    plt.tight_layout()
else:
    print('No inventory series available to plot')

# %% [markdown]
# ### Spread over time (RL)

# %%
if rl_state is not None and not rl_state.empty and 'spread' in rl_state.columns:
    spread_smoothed = rl_state['spread'].rolling(window=100, min_periods=1).mean()
    spread_smoothed.plot(figsize=(10, 3), title='Spread over time (rolling 100)', legend=True)
    plt.tight_layout()
else:
    print('No spread data found in RL STATE events')

# %% [markdown]
# ### Rewards and PnL per step

# %%
if rl_state is not None and not rl_state.empty:
    # Step reward
    rl_state['reward'].plot(figsize=(10,3), title='Step reward', label='reward')
    plt.legend()
    plt.tight_layout()

    # Rolling mean (100)
    rl_state['reward'].rolling(window=100, min_periods=1).mean().plot(figsize=(10,3), title='Reward rolling mean (100)', label='reward_roll100')
    plt.legend()
    plt.tight_layout()

    # Cumulative reward
    # rl_state['cum_reward'].plot(figsize=(10,3), title='Cumulative reward', label='cum_reward')
    # plt.legend()
    # plt.tight_layout()
else:
    print('No STATE events found in RL log')

# %% [markdown]
# ### Actions over time and Q proxy

# %%
# Build action label map for RLMM2 (symmetric offsets)
offsets = [1, 2, 3]  # change if you used different offsets
action_labels = {i: f"action {i} (±{o})" for i, o in enumerate(offsets)}

# Use RL state
state_df = rl_state.copy() if rl_state is not None else pd.DataFrame()
if 'time' in state_df.columns:
    state_df['time'] = pd.to_datetime(state_df['time'])
    state_df = state_df.set_index('time')
state_df = state_df.sort_index()

if not state_df.empty:
    action_counts = (
        state_df['last_action']
        .groupby(pd.Grouper(freq='5T'))
        .value_counts()
        .unstack(fill_value=0)
    )
    action_counts = action_counts.rename(columns=action_labels)
    ax = action_counts.plot.area(figsize=(20, 6), title='Action counts per 5 min')
    ax.legend(title='action', bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0.)
    plt.tight_layout()
else:
    print('No STATE events found in RL log')
# Out:
# /var/folders/4d/b_50cxsx369cdz1pzpjf8md40000gn/T/ipykernel_2208/136164856.py:15: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   .groupby(pd.Grouper(freq='5T'))

# %%
if rl_state is not None and not rl_state.empty:
    action_counts = (
        rl_state['last_action']
        .groupby(pd.Grouper(freq='5T'))
        .value_counts()
        .unstack(fill_value=0)
    )

    def sum_cols(df, cols):
        cols = [c for c in cols if c in df.columns]
        return df[cols].sum(axis=1) if cols else pd.Series(0, index=df.index)

    grouped = pd.DataFrame({
        'action_0': sum_cols(action_counts, [0]),
        'action_1': sum_cols(action_counts, [1]),
        'action_2': sum_cols(action_counts, [2]),
    })

    palette = {
        'action_0': '#1f77b4',
        'action_1': '#ff7f0e',
        'action_2': '#2ca02c',
    }

    ax = grouped.plot.area(
        figsize=(20, 10),
        color=[palette[c] for c in grouped.columns],
        title='Action counts per 5 min (grouped)',
    )
    ax.legend(title='action groups', bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0.)
    plt.tight_layout()
else:
    print('No STATE events found in RL log')
# Out:
# /var/folders/4d/b_50cxsx369cdz1pzpjf8md40000gn/T/ipykernel_2208/2323437729.py:4: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   .groupby(pd.Grouper(freq='5T'))

# %% [markdown]
# ### State visitation heatmap

# %%
spread_bin_size = 5      # ticks
inventory_bin_size = 10  # units

if rl_state is not None and not rl_state.empty:
    visit = (
        rl_state.groupby(['inventory_bin', 'spread_bin'])
                .size()
                .unstack(fill_value=0)
                .sort_index()
    )
    inv_bins = visit.index.values
    spr_bins = visit.columns.values

    spr_labels = [(b + 1) * spread_bin_size for b in spr_bins]
    inv_labels = [(b + 1) * inventory_bin_size for b in inv_bins]

    plt.figure(figsize=(6, 4))
    plt.imshow(
        visit.values,
        origin='lower',
        aspect='auto',
        extent=[spr_bins.min() - 0.5, spr_bins.max() + 0.5,
                inv_bins.min() - 0.5, inv_bins.max() + 0.5],
    )
    plt.colorbar(label='visits')
    plt.xticks(ticks=spr_bins, labels=spr_labels)
    plt.yticks(ticks=inv_bins, labels=inv_labels)
    plt.xlabel('spread (max ticks in bin)')
    plt.ylabel('inventory (max units in bin)')
    plt.title('State visitation')
    plt.tight_layout()
else:
    print('No STATE events found in RL log')

# %% [markdown]
# ## Order book and fundamental

# %%
# Mid-price overlay for RLMM2, simpleMM, and orderbook mid
log_dir = params['log_dir']
simple_log_dir = params['simple_log_dir']

def mid_from_state(log_dir, pattern, label):
    files = sorted(log_dir.glob(pattern))
    if not files:
        print(f'No {pattern} found in {log_dir}')
        return None
    log = pd.read_pickle(files[0])
    state_rows = log[log['EventType'] == 'STATE']
    if state_rows.empty:
        print(f'No STATE events in {files[0].name}')
        return None
    df = pd.DataFrame(list(state_rows['Event'])).set_index('time')
    df.index = pd.to_datetime(df.index)
    if 'mid' not in df.columns:
        print(f"No 'mid' field in {files[0].name}")
        return None
    return df['mid'].rename(label)

rl_mid = mid_from_state(log_dir, 'RL_MM2_*.bz2', 'RLMM2')
simple_mid = mid_from_state(simple_log_dir, 'SIMPLE_MM_*.bz2', 'simpleMM')

top_mid = None
# Order book snapshots (expects a file already chosen or globbed)
if 'orderbook_file' in globals() and orderbook_file:
    ob = pd.read_pickle(orderbook_file)
    print('Orderbook columns:', list(ob.columns))

    def find_col(columns, substrings):
        for col in columns:
            name = ' '.join(col) if isinstance(col, tuple) else str(col)
            lname = name.lower()
            if all(sub in lname for sub in substrings):
                return col
        return None

    bid_price_col = find_col(ob.columns, ['best', 'bid']) or find_col(ob.columns, ['bid', 'price'])
    ask_price_col = find_col(ob.columns, ['best', 'ask']) or find_col(ob.columns, ['ask', 'price'])
    if bid_price_col and ask_price_col:
        top = ob[[bid_price_col, ask_price_col]].copy()
        top.columns = ['best_bid_price', 'best_ask_price']
        top['mid'] = (top['best_bid_price'] + top['best_ask_price']) / 2
        top['spread'] = top['best_ask_price'] - top['best_bid_price']
        top_mid = top['mid'].rename('orderbook_mid')
        top[['spread']].plot(figsize=(10,3), title='Quoted spread', legend=True)
        plt.tight_layout()
    else:
        display(ob.head())
else:
    print('Orderbook file not found')

fundamental_series = None
# Fundamental path
fund_file = next(params['log_dir'].glob('fundamental_*.bz2'), None)
if fund_file:
    fundamental = pd.read_pickle(fund_file).reset_index()
    fundamental['FundamentalTime'] = pd.to_datetime(fundamental['FundamentalTime'])
    fundamental_series = fundamental.set_index('FundamentalTime')['FundamentalValue'].rename('Fundamental')
    fundamental.plot(x='FundamentalTime', y='FundamentalValue', legend=True, figsize=(10,3), title='Fundamental path')
    plt.tight_layout()
else:
    print('Fundamental file not found')

series = [s for s in [rl_mid, simple_mid, top_mid, fundamental_series] if s is not None]
if series:
    mid_df = pd.concat(series, axis=1).sort_index()
    mid_df.plot(figsize=(12, 4), title='Mid Price (RLMM2 vs simpleMM)')
    plt.xlabel('Time')
    plt.ylabel('Mid Price (cents)')
    plt.tight_layout()
else:
    print('No midprice series available to plot')
# Out:
# Orderbook file not found

# %% [markdown]
# ### Q-values over time

# %%
if rl_state is not None and not rl_state.empty and 'q_max' in rl_state.columns:
    rl_state['q_max'].plot(figsize=(10,3), title='Max Q for current state', label='q_max')
    plt.legend()
    plt.tight_layout()
    if 'greedy_action' in rl_state.columns:
        rl_state['greedy_action'].plot(figsize=(10,3), title='Greedy action over time', label='greedy_action')
        plt.legend()
        plt.tight_layout()
else:
    print('No Q info in STATE events')
